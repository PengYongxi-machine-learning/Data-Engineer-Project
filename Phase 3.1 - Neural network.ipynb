# %% [markdown]
# #### Modules

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import root_mean_squared_error, r2_score

import keras
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# #### Train and test split

# %%
# Load dataset
df = pd.read_csv('Use dataset.csv')
X_c = df.drop(columns = ['Fuel Consumption City (L/100 km)', 'Fuel Consumption Hwy (L/100 km)']) # Transmission Type_AM
city = df['Fuel Consumption City (L/100 km)']
X_h = df.drop(columns = ['Fuel Consumption City (L/100 km)', 'Fuel Consumption Hwy (L/100 km)']) # Vehicle Class_ MINICOMPACT
hwy = df['Fuel Consumption Hwy (L/100 km)']

# Split the data into training and testing sets (80% train, 20% test)
xc_train, xc_test, c_tr, c_te = train_test_split(X_c, city, test_size=0.2, random_state=42)
xh_train, xh_test, h_tr, h_te = train_test_split(X_h, hwy, test_size=0.2, random_state=42)

#Normalize the X data
scaler = StandardScaler()
xc_tr, xc_te  = scaler.fit_transform(xc_train) , scaler.fit_transform(xc_test)
xh_tr, xh_te  = scaler.fit_transform(xh_train) , scaler.fit_transform(xh_test)

# %% [markdown]
# #### Build Neural Network Model
